# %%
def calc(stream,storage_size): 
    t = storage_size/stream 
    t_min = t/60 
    t_h = t/3600 
    t_d = t/(3600*24)
    t_y = t/(3600*24*365)

    print("Time: s: ", t, "m: ", t_min, " d: ", t_d, "years: ", t_y)

# %%
for storage_name, storage_size in [["DVD", 4.71 * 10**9 * 8 ], ["SSD", 8*2*10**12], ["Harry", 4*10**9]]: 
    print("checking for keys saved on ", storage_name, "which is equiv to bit: ", storage_size)
    for stream, stream_size in [["Text chat", 40], ["Spech", 13.2*10**3], ["Video chat", 4000*10**3]]: 
        print("checking for ", stream)
        calc(stream_size, storage_size)
    print("\n")
# Out:
# checking for keys saved on  DVD which is equiv to bit:  37680000000.0
# checking for  Text chat
# Time: s:  942000000.0 m:  15700000.0  d:  10902.777777777777 years:  29.87062404870624
# checking for  Spech
# Time: s:  2854545.4545454546 m:  47575.757575757576  d:  33.03872053872054 years:  0.0905170425718371
# checking for  Video chat
# Time: s:  9420.0 m:  157.0  d:  0.10902777777777778 years:  0.00029870624048706243
#
#
# checking for keys saved on  SSD which is equiv to bit:  16000000000000
# checking for  Text chat
# Time: s:  400000000000.0 m:  6666666666.666667  d:  4629629.62962963 years:  12683.916793505834
# checking for  Spech
# Time: s:  1212121212.121212 m:  20202020.2020202  d:  14029.18069584736 years:  38.436111495472225
# checking for  Video chat
# Time: s:  4000000.0 m:  66666.66666666667  d:  46.2962962962963 years:  0.12683916793505834
#
#
# checking for keys saved on  Harry which is equiv to bit:  4000000000
# checking for  Text chat
# ...

# %%
import math 
for i in range(1,10): 
    print(math.log2(i))
    print(i* 1/i * -math.log2(1/i))
# Out:
# 0.0
# -0.0
# 1.0
# 1.0
# 1.584962500721156
# 1.5849625007211563
# 2.0
# 2.0
# 2.321928094887362
# 2.321928094887362
# 2.584962500721156
# 2.584962500721156
# 2.807354922057604
# 2.807354922057604
# 3.0
# 3.0
# 3.169925001442312
# 3.1699250014423126
