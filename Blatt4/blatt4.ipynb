# %%
SBOX = [

]

INV_SBOX = [

]

# %%
def f1(x, k):
    return SBOX[(x + k) % 256]

def f2(x, k):
    return INV_SBOX[(x + k) % 256]

# %%
def encrypt(m0, m1, k): 
    l2 = f1(m1,k)^m0 
    r2 = f2(f1(m1,k)^m0,k)^m1 
    return l2, r2 

def decrypt(l2, r2, k): 
    m1 = f2(l2, k) ^r2 
    m0 = f1(f2(l2,k)^r2,k)^l2
    return m0, m1

# %%
print(encrypt(73,78, 214)) 
print(decrypt(127,163,214))
# Out:
# (127, 163)
# (73, 78)

# %%
import random

def count_bits(x):
    return bin(x).count("1")

import random

def confusion_test(num_tests=100):
    difs = []
    bit_flip_positions = [0] * 16  # 16 Bits für 2 Bytes Output

    for _ in range(num_tests):
        m0 = random.randint(0, 255)
        m1 = random.randint(0, 255)

        key_base = random.randint(0, 255)

        bit_to_flip = 1 << random.randint(0, 7)
        key_prime = key_base ^ bit_to_flip

        c_base = encrypt(m0, m1, key_base)
        c_prime = encrypt(m0, m1, key_prime)

        # XOR der Outputs
        diff0 = c_base[0] ^ c_prime[0]
        diff1 = c_base[1] ^ c_prime[1]

        # Gesamtanzahl Bitunterschiede
        diff = count_bits(diff0) + count_bits(diff1)
        difs.append(diff)

        # 🔥 Bitpositionen tracken
        for i in range(8):
            if diff0 & (1 << i):
                bit_flip_positions[i] += 1
            if diff1 & (1 << i):
                bit_flip_positions[i + 8] += 1

    avg = sum(difs) / len(difs)
    return avg, difs, bit_flip_positions

# %%
import matplotlib.pyplot as plt

avg, difs, pos = confusion_test(1000)

print("Average bit difference:", avg)

# --------- HISTOGRAMM ----------
plt.figure(figsize=(10,5))

plt.hist(difs, bins=range(min(difs), max(difs) + 2),
         edgecolor='black', alpha=0.75)

plt.axvline(avg, color='red', linestyle='--', label=f"Avg = {avg:.2f}")

plt.title("Confusion Test - Distribution of Bit Differences")
plt.xlabel("Bit differences")
plt.ylabel("Number tests")
plt.legend()
plt.grid(True)

import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

positions = np.arange(len(pos))  # 0–15

# Balken
plt.bar(positions, pos, edgecolor='black', alpha=0.75, label="Counts")

# 🔥 Lineare Regression (Trend)
coeffs = np.polyfit(positions, pos, 1)  # Grad 1 = Gerade
trendline = np.poly1d(coeffs)

plt.plot(positions, trendline(positions), linestyle='--', label="Trend")

plt.title("Confusion Test - Bit Flip Positions with Trend")
plt.xlabel("Bit position (0–15)")
plt.ylabel("Number of flips")

plt.xticks(positions)
plt.legend()
plt.grid(True)

plt.show()
# Out:
# Average bit difference: 7.929

# %%
import random
import matplotlib.pyplot as plt

def count_bits(x):
    return bin(x).count("1")

def diffusion_test(num_tests=100):
    difs = []

    for _ in range(num_tests):
        # gleiche Message
        m0 = random.randint(0, 255)
        m1 = random.randint(0, 255)

        # 1 Bit in der Message flippen
        bit_to_flip = 1 << random.randint(0, 7)

        m0_prime = m0
        m1_prime = m1

        # zufällig entscheiden, welches Byte geändert wird
        if random.random() < 0.5:
            m0_prime ^= bit_to_flip
        else:
            m1_prime ^= bit_to_flip

        # Schlüssel bleibt gleich (!! wichtig für diffusion)
        key = random.randint(0, 255)

        c_base = encrypt(m0, m1, key)
        c_prime = encrypt(m0_prime, m1_prime, key)

        diff = count_bits(c_base[0] ^ c_prime[0]) + \
               count_bits(c_base[1] ^ c_prime[1])

        difs.append(diff)

    avg = sum(difs) / len(difs)
    return avg, difs


# --------- AUSFÜHREN ----------
avg, difs = diffusion_test(200)

print("Average bit difference (diffusion):", avg)

# --------- HISTOGRAMM ----------
plt.figure(figsize=(10,5))

plt.hist(difs, bins=range(min(difs), max(difs) + 2),
         edgecolor='black', alpha=0.75)

plt.axvline(avg, color='red', linestyle='--', label=f"Avg = {avg:.2f}")

plt.title("Diffusion Test - 1 Bit Message Change")
plt.xlabel("Bit differences")
plt.ylabel("Number of tests")
plt.legend()
plt.grid(True)

plt.show()
# Out:
# Average bit difference (diffusion): 6.6

# %% [markdown]
# #  d) fixed pts

# %%
number = 0
for k in range(0,256): 
    for m0 in range(0,256): 
        for m1 in range(0,256): 
            res0, res1 = encrypt(m0, m1, k)
            if res0 == m0: 
                if res1 == m1: 
                    #print("both match")
                    #print("m1: ", m1, "m0: ", m0, "k:", k)
                    number +=1

# %%
print("had matches: ", number, " and there are combinations: ", 256**3)
# Out:
# had matches:  256  and there are combinations:  16777216
